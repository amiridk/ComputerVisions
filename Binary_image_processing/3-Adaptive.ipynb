# %% [markdown]
# # this is my note for starting Image Processing

# %% [markdown]
# ### Adaptive thresholding is a crucial technique in image processing used to enhance image segmentation by dynamically adjusting the threshold value for different regions of an image. Unlike global thresholding, which applies a single threshold value to the entire image, adaptive thresholding considers local variations in intensity, making it more effective for images with uneven lighting or varying contrast.
# > This method typically involves dividing the image into smaller regions and calculating a threshold for each region based on its local pixel intensity distribution, often using methods like the mean or Gaussian-weighted sum of the neighborhood pixels. By adapting to local conditions, adaptive thresholding can better distinguish between objects and background, improving the accuracy of tasks such as text detection, edge detection, and object recognition in complex images.
#
# <div style="display: grid; grid-template-columns: repeat(2, 1fr); gap: 10px;">
#   <h1 style="color: green;">- Adaptive Thresholding</h1>
#   <h4 style="color: green;">1- Gaussian C <br/> 2- Mean C </h4>
#
# </div>
# <div style="display: grid; grid-template-columns: repeat(2, 1fr); gap: 10px;">
#   <h4 style="color:rgb(86, 143, 143) ;">- Amirreza zare <br/> - 3/7/2025 </h4>
# </div>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


original_image = cv2.imread('../data/images/sudoku.jpg', 0)
noise_removed_image = cv2.medianBlur(original_image,5)

_,output1 = cv2.threshold(original_image,127,255,cv2.THRESH_BINARY)
output2 = cv2.adaptiveThreshold(original_image,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,2)
output3 = cv2.adaptiveThreshold(original_image,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,11,2)

_,output4 = cv2.threshold(noise_removed_image,127,255,cv2.THRESH_BINARY)
output5 = cv2.adaptiveThreshold(noise_removed_image,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,2)
output6 = cv2.adaptiveThreshold(noise_removed_image,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,11,2)


plt.figure(figsize=[15,15])
plt.subplot(332);plt.imshow(original_image, cmap='gray');plt.title("Original");
plt.subplot(333);plt.imshow(noise_removed_image, cmap='gray');plt.title("Noise removed");

plt.subplot(334);plt.imshow(output1, cmap='gray');plt.title("Global Thresholding (v = 127)");
plt.subplot(335);plt.imshow(output2, cmap='gray');plt.title("Adaptive Mean Thresholding");
plt.subplot(336);plt.imshow(output3, cmap='gray');plt.title("Adaptive Gaussian Thresholding");

plt.subplot(337);plt.imshow(output4, cmap='gray');plt.title("Global Thresholding + noise removal");
plt.subplot(338);plt.imshow(output5, cmap='gray');plt.title("Adaptive Mean + noise removal");
plt.subplot(339);plt.imshow(output6, cmap='gray');plt.title("Adaptive Gaussian + noise removal");

# %%
# FREE UP MEMORY AND RESOURCES
import gc

gc.collect()
# %reset -f
